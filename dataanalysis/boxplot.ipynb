# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\ASUS\\Documents\\electronics.csv")
df.head()
# Out:
#    item_id  user_id  rating   timestamp model_attr                category  \
# 0        0        0       5  13-06-1999     Female  Portable Audio & Video
# 1        0        1       5  14-06-1999     Female  Portable Audio & Video
# 2        0        2       3  17-06-1999     Female  Portable Audio & Video
# 3        0        3       1  01-07-1999     Female  Portable Audio & Video
# 4        0        4       2  06-07-1999     Female  Portable Audio & Video
#
#   brand  year user_attr  split
# 0   NaN  1999       NaN      0
# 1   NaN  1999       NaN      0
# 2   NaN  1999       NaN      0
# 3   NaN  1999       NaN      0
# 4   NaN  1999       NaN      0

# %%
df.shape
# Out:
# (1048575, 10)

# %%
df.describe(include="all")
# Out:
#              item_id       user_id        rating   timestamp model_attr  \
# count   1.048575e+06  1.048575e+06  1.048575e+06     1048575    1048575
# unique           NaN           NaN           NaN        5753          3
# top              NaN           NaN           NaN  20-01-2016     Female
# freq             NaN           NaN           NaN        1692     396632
# mean    3.881872e+03  4.579017e+05  4.062872e+00         NaN        NaN
# std     2.430835e+03  2.719007e+05  1.361620e+00         NaN        NaN
# min     0.000000e+00  0.000000e+00  1.000000e+00         NaN        NaN
# 25%     1.823000e+03  2.214330e+05  4.000000e+00         NaN        NaN
# 50%     3.500000e+03  4.519310e+05  5.000000e+00         NaN        NaN
# 75%     5.795000e+03  6.912885e+05  5.000000e+00         NaN        NaN
# max     9.489000e+03  9.418600e+05  5.000000e+00         NaN        NaN
#
#           category     brand          year user_attr         split
# count      1048575    273310  1.048575e+06    144408  1.048575e+06
# unique          10        50           NaN         2           NaN
# top     Headphones  Logitech           NaN      Male           NaN
# freq        295747     23360           NaN     73112           NaN
# mean           NaN       NaN  2.012688e+03       NaN  1.635172e-01
# std            NaN       NaN  2.670931e+00       NaN  5.318743e-01
# min            NaN       NaN  1.999000e+03       NaN  0.000000e+00
# 25%            NaN       NaN  2.012000e+03       NaN  0.000000e+00
# 50%            NaN       NaN  2.013000e+03       NaN  0.000000e+00
# 75%            NaN       NaN  2.015000e+03       NaN  0.000000e+00
# max            NaN       NaN  2.018000e+03       NaN  2.000000e+00

# %%
df.isnull().sum()
# Out:
# item_id            0
# user_id            0
# rating             0
# timestamp          0
# model_attr         0
# category           0
# brand         775265
# year               0
# user_attr     904167
# split              0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Rating distribution across categories
plt.figure(figsize=(12,6))  # wider for better category spacing
sns.boxplot(x='category', y='rating', data=df)

# Rotate x-axis labels for readability
plt.xticks(rotation=45, ha='right')

plt.title("Rating Distribution Across Product Categories", fontsize=14)
plt.xlabel("Product Category")
plt.ylabel("Customer Rating")

plt.show()
